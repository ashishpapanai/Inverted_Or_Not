# %%
import tensorflow as tf
saved_model = tf.keras.models.load_model('invertedImages.h5')

# %%
from ipywidgets import FileUpload
from IPython.display import display
upload = FileUpload(accept='.jpg', multiple=True)
display(upload)
# Out:
# FileUpload(value={}, accept='.jpg', description='Upload', multiple=True)

# %%
import io
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
for name, file_info in upload.value.items():
    img = Image.open(io.BytesIO(file_info['content']))
imshow(np.asarray(img))

# %%
img = img.resize((150,150))
x = img_to_array(img)                         
x = x.reshape((1,) + x.shape)                 
x /= 255.0
classes = saved_model.predict(x)
if classes[0]>0.5:
    print("Uploaded image is Not Inverted")
else:
    print("Uploaded image is Inverted")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASHISH~1\AppData\Local\Temp/ipykernel_6060/3333506735.py in <module>
#       1 img = img.resize((150,150))
# ----> 2 x = img_to_array(img)
#       3 x = x.reshape((1,) + x.shape)
#       4 x /= 255.0
#       5 classes = saved_model.predict(x)
#
# NameError: name 'img_to_array' is not defined
